# %% [markdown]
# <a href="https://colab.research.google.com/github/gowthamkaruturi/ai-engineer-roadmap/blob/main/linear_regression.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import sys

assert sys.version_info >= (3, 10)
